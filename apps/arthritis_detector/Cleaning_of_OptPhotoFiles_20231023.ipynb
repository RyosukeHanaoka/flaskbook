# %% [markdown]
# #OptPhotoFilesを整備する。
# OptPhotoFilesというディレクトリに含まれているファイルを、解析に適した形式に整える作業。
# 注意：本ノートブックは失われたノートの復元物です。実際の使用には、幾らかの修正が必要になる可能性があります。既存のファイルを破損しないように注意してください。

# %% [markdown]
# #出発点となるファイルの生成（バックアップファイルから）
# "/content/drive/MyDrive/OptPhotoFiles/optPhotoFilesBackUp/optPhotoFiles/"には、nonRA_left_HandとnonRA_Right_Handというディレクトリが存在し、その中にたくさんの雑多な画像ファイルが含まれています。ファイル形式はjpgが主体ですが、heicが含まれていたり、ひどいものではhtmlが含まれていたりします。そこでまず、
# /content/drive/MyDrive/OptPhotoFiles/optPhotoFilesBackUp/optPhotoFiles/nonRA_Right_Handに含まれているファイルのファイル形式を統一します。最初に全てコピーして、/content/drive/MyDrive/OptPhotoFiles/optPhotoFiles/nonRA/nonRA_Right_Handを新規に作成し、その中にファイルを格納します。

# %% [markdown]
# まず、Google Driveをマウントする。

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %pip install pyheif
# Out:
# Collecting pyheif
#   Downloading pyheif-0.7.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 59.1 MB/s eta 0:00:00
# Requirement already satisfied: cffi>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from pyheif) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.0->pyheif) (2.21)
# Installing collected packages: pyheif
# Successfully installed pyheif-0.7.1

# %%
import os
import shutil
from PIL import Image
import pyheif
import pandas as pd
import csv

# %% [markdown]
# #ファイル形式の統一（jpg以外の画像形式をjpgに変換、htmlファイルは削除）
# 次に、ディレクトリをコピーし、ファイル形式の統一を行います。

# %%
import os
import shutil
from PIL import Image

# ディレクトリのコピー
src_dir = "/content/drive/MyDrive/OptPhotoFiles/optPhotoFilesBackUp/optPhotoFiles/nonRA_Right_Hand"
dst_dir = "/content/drive/MyDrive/OptPhotoFiles/optPhotoFiles/nonRA/nonRA_Right_Hand"

if not os.path.exists(dst_dir):
    shutil.copytree(src_dir, dst_dir)

# ファイル形式の統一
for root, dirs, files in os.walk(dst_dir):
    for file in files:
        file_path = os.path.join(root, file)
        file_ext = os.path.splitext(file)[1].lower()

        # htmlファイルの場合、削除
        if file_ext == '.html':
            os.remove(file_path)
        # heicファイルの場合、jpgに変換
        elif file_ext == '.heic':
            with Image.open(file_path) as im:
                new_file_path = os.path.join(root, os.path.splitext(file)[0] + '.jpg')
                im.convert("RGB").save(new_file_path, "JPEG")
                os.remove(file_path)

print("Process completed!")

# %% [markdown]
# このコードを実行すると、nonRA_Right_Hand ディレクトリの内容が nonRA/nonRA_Right_Hand にコピーされ、ファイル形式が統一されます。

# %% [markdown]
# 念の為、各ディレクトリに含まれるファイル数を表示する。

# %%
import os

# 対象のディレクトリ
target_dir = "/content/drive/MyDrive/OptPhotoFiles/optPhotoFilesBackUp/optPhotoFiles/nonRA_Right_Hand"

# ファイル数を計算
file_count = sum([len(files) for _, _, files in os.walk(target_dir)])

print(f"Total number of files in {target_dir}: {file_count}")
# Out:
# Total number of files in /content/drive/MyDrive/OptPhotoFiles/optPhotoFilesBackUp/optPhotoFiles/nonRA_Right_Hand: 1208

# %%
# 対象のディレクトリ
target_dir = "/content/drive/MyDrive/OptPhotoFiles/optPhotoFiles/nonRA/nonRA_Right_Hand"

# ファイル数を計算
file_count = sum([len(files) for _, _, files in os.walk(target_dir)])

print(f"Total number of files in {target_dir}: {file_count}")
# Out:
# Total number of files in /content/drive/MyDrive/OptPhotoFiles/optPhotoFiles/nonRA/nonRA_Right_Hand: 1208

# %% [markdown]
# 同様の処理を左手でも施行する。

# %%
# ディレクトリのコピー
src_dir = "/content/drive/MyDrive/OptPhotoFiles/optPhotoFilesBackUp/optPhotoFiles/nonRA_Left_Hand"
dst_dir = "/content/drive/MyDrive/OptPhotoFiles/optPhotoFiles/nonRA/nonRA_Left_Hand"

if not os.path.exists(dst_dir):
    shutil.copytree(src_dir, dst_dir)

# ファイル形式の統一
for root, dirs, files in os.walk(dst_dir):
    for file in files:
        file_path = os.path.join(root, file)
        file_ext = os.path.splitext(file)[1].lower()

        # htmlファイルの場合、削除
        if file_ext == '.html':
            os.remove(file_path)
        # heicファイルの場合、jpgに変換
        elif file_ext == '.heic':
            with Image.open(file_path) as im:
                new_file_path = os.path.join(root, os.path.splitext(file)[0] + '.jpg')
                im.convert("RGB").save(new_file_path, "JPEG")
                os.remove(file_path)

print("Process completed!")

# %%
# 対象のディレクトリ
target_dir = "/content/drive/MyDrive/OptPhotoFiles/optPhotoFilesBackUp/optPhotoFiles/nonRA_Left_Hand"

# ファイル数を計算
file_count = sum([len(files) for _, _, files in os.walk(target_dir)])

print(f"Total number of files in {target_dir}: {file_count}")
# Out:
# Total number of files in /content/drive/MyDrive/OptPhotoFiles/optPhotoFilesBackUp/optPhotoFiles/nonRA_Left_Hand: 1200

# %%
# 対象のディレクトリ
target_dir = "/content/drive/MyDrive/OptPhotoFiles/optPhotoFiles/nonRA/nonRA_Left_Hand"

# ファイル数を計算
file_count = sum([len(files) for _, _, files in os.walk(target_dir)])

print(f"Total number of files in {target_dir}: {file_count}")
# Out:
# Total number of files in /content/drive/MyDrive/OptPhotoFiles/optPhotoFiles/nonRA/nonRA_Left_Hand: 1200

# %% [markdown]
# ここからは、バックアップファイルの破損防止のため、/content/drive/MyDrive/OptPhotoFiles/optPhotoFiles/nonRA/nonRA_Right_Handと、/content/drive/MyDrive/OptPhotoFiles/optPhotoFiles/nonRA/nonRA_Left_Handを改変する。

# %% [markdown]
# #拡張子の統一
# ここからは、/content/drive/MyDrive/OptPhotoFiles/optPhotoFiles/nonRA/nonRA_Right_Handを改変します。heicは全てjpgに変換し、jpgファイルの中で、拡張子が”jpg”以外の表記の場合、それらの拡張子をjpgに統一してください。ファイルが破損しているなどの理由で変換できない場合は削除していいです。ただし、削除したファイル名を教えてください。

# %%
# %pip install pyheif
from PIL import Image
import os
import pyheif

src_dir = "/content/drive/MyDrive/OptPhotoFiles/optPhotoFiles/nonRA/nonRA_Right_Hand"
dst_dir = "/content/drive/MyDrive/OptPhotoFiles/optPhotoFiles/nonRA/nonRA_Right_Hand_2nd"

if not os.path.exists(dst_dir):
    os.makedirs(dst_dir)

failed_files = []

for root, _, files in os.walk(src_dir):
    for file in files:
        src_path = os.path.join(root, file)
        filename, ext = os.path.splitext(file)

        try:
            # Convert heic files to jpg
            if ext.lower() == '.heic':
                heif_file = pyheif.read(src_path)
                image = Image.frombytes(
                    heif_file.mode,
                    heif_file.size,
                    heif_file.data,
                    "raw",
                    heif_file.mode,
                    heif_file.stride,
                )
                dst_path = os.path.join(dst_dir, filename + '.jpg')
                image.save(dst_path, "JPEG")

            # Rename other jpg files to ensure the extension is ".jpg"
            elif ext.lower() in ['.jpeg', '.jpg']:
                dst_path = os.path.join(dst_dir, filename + '.jpg')
                image = Image.open(src_path)
                image.save(dst_path, "JPEG")

        except Exception as e:
            print(f"Error processing file {file}: {e}")
            failed_files.append(file)

if failed_files:
    print("Failed to process the following files:")
    for file in failed_files:
        print(file)
else:
    print("All files processed successfully!")

# %% [markdown]
# ファイル数の確認を行う。

# %%
# 対象のディレクトリ
target_dir = "/content/drive/MyDrive/OptPhotoFiles/optPhotoFiles/nonRA/nonRA_Right_Hand_2nd"

# ファイル数を計算
file_count = sum([len(files) for _, _, files in os.walk(target_dir)])

print(f"Total number of files in {target_dir}: {file_count}")
# Out:
# Total number of files in /content/drive/MyDrive/OptPhotoFiles/optPhotoFiles/nonRA/nonRA_Right_Hand_2nd: 1207

# %% [markdown]
# ここまでと同じ処理を/content/drive/MyDrive/OptPhotoFiles/optPhotoFilesBackUp/nonRA_Left_Handに含まれているファイルにも行なう。

# %%
src_dir = "/content/drive/MyDrive/OptPhotoFiles/optPhotoFiles/nonRA/nonRA_Left_Hand"
dst_dir = "/content/drive/MyDrive/OptPhotoFiles/optPhotoFiles/nonRA/nonRA_Left_Hand_2nd"

if not os.path.exists(dst_dir):
    os.makedirs(dst_dir)

failed_files = []

for root, _, files in os.walk(src_dir):
    for file in files:
        src_path = os.path.join(root, file)
        filename, ext = os.path.splitext(file)

        try:
            # Convert heic files to jpg
            if ext.lower() == '.heic':
                heif_file = pyheif.read(src_path)
                image = Image.frombytes(
                    heif_file.mode,
                    heif_file.size,
                    heif_file.data,
                    "raw",
                    heif_file.mode,
                    heif_file.stride,
                )
                dst_path = os.path.join(dst_dir, filename + '.jpg')
                image.save(dst_path, "JPEG")

            # Rename other jpg files to ensure the extension is ".jpg"
            elif ext.lower() in ['.jpeg', '.jpg']:
                dst_path = os.path.join(dst_dir, filename + '.jpg')
                image = Image.open(src_path)
                image.save(dst_path, "JPEG")

        except Exception as e:
            print(f"Error processing file {file}: {e}")
            failed_files.append(file)

if failed_files:
    print("Failed to process the following files:")
    for file in failed_files:
        print(file)
else:
    print("All files processed successfully!")

# %% [markdown]
# ファイル数の確認を行う。

# %%
# 対象のディレクトリ
target_dir = "/content/drive/MyDrive/OptPhotoFiles/optPhotoFiles/nonRA/nonRA_Left_Hand_2nd"

# ファイル数を計算
file_count = sum([len(files) for _, _, files in os.walk(target_dir)])

print(f"Total number of files in {target_dir}: {file_count}")
# Out:
# Total number of files in /content/drive/MyDrive/OptPhotoFiles/optPhotoFiles/nonRA/nonRA_Left_Hand_2nd: 1199

# %% [markdown]
# #ディレクトリを新規に作成し、統一したファイル名のファイルを格納する。
# さらに/content/drive/MyDrive/OptPhotoFiles/optPhotoFiles/nonRA/nonRA_Right_Hand_2ndに含まれているファイルのファイル名を統一します。optPhotoTable_controlsに記載されている順番に通し番号をふり、今までのファイル名を、nonRA_right_hand_通し番号_.jpgとなるように変更し、新たに/content/drive/MyDrive/OptPhotoFiles/optPhotoFiles/nonRA/nonRA_Right_Hand_3rdを作成し、そこに格納してください。optPhotoTable_controlsには、新たな行に新しいファイル名を記入してください。
#
#
# 次に、ファイル名の変更と、/content/drive/MyDrive/OptPhotoFiles/optPhotoTable/に格納されているoptPhotoTable_controlsの改変作業です。
# optPhotoTable_controlsの構造は以下の通り。
# 先頭行は見出し。
# 0列目：time_stamp（日時と時間）
# 1列目：informed_consent（０と１の２区分変数）
# 2列目：age（0から100までの整数）
# 3列目：female（０と１の２区分変数）
# 4列目：RA（０と１の２区分変数）
# 5列目：arthralgia（０と１の２区分変数）
# 6列目：right_hand_url（文字列）
# 7列目：left_hand_url（文字列）
# 8列目：crowdworks_username（全角半角混在の文字列）
# 9列目：right_hand_filename（全角半角混在の文字列）
# 10列目：left_hand_filename（全角半角混在の文字列）

# %%
import pandas as pd
import os
import shutil
from PIL import Image

src_dir = "/content/drive/MyDrive/OptPhotoFiles/optPhotoFiles/nonRA/nonRA_Right_Hand_2nd"
dst_dir = "/content/drive/MyDrive/OptPhotoFiles/optPhotoFiles/nonRA/nonRA_Right_Hand_3rd"

if not os.path.exists(dst_dir):
    shutil.copytree(src_dir, dst_dir)

print("Files copied successfully!")
# Out:
# Files copied successfully!

# %%
import os
import pandas as pd

# CSVファイルの読み込み
df = pd.read_csv('/content/drive/MyDrive/optPhotoTable_controls.csv')

# 画像ファイルのパス
directory_path = '/content/drive/MyDrive/OptPhotoFiles/optPhotoFiles/nonRA/nonRA_Right_Hand_3rd'

# ディレクトリ内のファイル名一覧を取得
file_list = os.listdir(directory_path)

# 新しいファイル名を保存するためのリスト
new_filenames = []

# 画像ファイルの照合とリネーム
for index, row in df.iterrows():
    original_name = row['right_hand_filename'].split('.')[0]  # 拡張子を除去
    for file in file_list:
        if original_name in file:  # ファイル名が一致するかどうか
            # 新しいファイル名の作成
            new_name = f"nonRA_right_hand_{index+1}.{file.split('.')[-1]}"
            # ファイルのリネーム
            os.rename(os.path.join(directory_path, file), os.path.join(directory_path, new_name))
            # 新しいファイル名をリストに追加
            new_filenames.append(new_name)
            break
    else:
        # ファイル名が一致しなかった場合、元のファイル名を保持
        new_filenames.append(row['right_hand_filename'])

# DataFrameに新しいファイル名の列を追加
df["new_right_hand_filename"] = new_filenames

# DataFrameをCSVファイルとして保存
df.to_csv('/content/drive/MyDrive/optPhotoTable_controls_updated.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-24aabddef744> in <cell line: 17>()
#      22             new_name = f"nonRA_right_hand_{index+1}.{file.split('.')[-1]}"
#      23             # ファイルのリネーム
# ---> 24             os.rename(os.path.join(directory_path, file), os.path.join(directory_path, new_name))
#      25             # 新しいファイル名をリストに追加
#      26             new_filenames.append(new_name)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/OptPhotoFiles/optPhotoFiles/nonRA/nonRA_Right_Hand_3rd/右 - KAZME.JPG' -> '/content/drive/MyDrive/OptPhotoFiles/optPhotoFiles/nonRA/nonRA_Right_Hand_3rd/nonRA_right_hand_863.JPG'

# %%
import os
import pandas as pd

# CSVファイルを読み込む
csv_path = "/content/drive/MyDrive/optPhotoTable_controls.csv"
df = pd.read_csv(csv_path)

# CSVからright_hand_filenameのリストを取得
csv_filenames = [str(name).split('.')[0] for name in df['right_hand_filename'].dropna()]

# 実際のディレクトリのファイルリストを取得
directory_path = "/content/drive/MyDrive/OptPhotoFiles/optPhotoFiles/nonRA/nonRA_Right_Hand_3rd"
actual_filenames = [file.split('.')[0] for file in os.listdir(directory_path) if os.path.isfile(os.path.join(directory_path, file))]

# CSVにはあるがディレクトリにはないファイルを確認
missing_in_directory = set(csv_filenames) - set(actual_filenames)

# ディレクトリにはあるがCSVにはないファイルを確認
missing_in_csv = set(actual_filenames) - set(csv_filenames)

print("CSVには存在するがディレクトリには存在しないファイル：")
print(missing_in_directory)
print("\nディレクトリには存在するがCSVには存在しないファイル：")
print(missing_in_csv)
# Out:
# CSVには存在するがディレクトリには存在しないファイル：
RA_right_hand_790', 'nonRA_right_hand_648', 'nonRA_right_hand_208', 'nonRA_right_hand_620', 'nonRA_right_hand_332', 'nonRA_right_hand_819', 'nonRA_right_hand_217', 'nonRA_right_hand_228', 'nonRA_right_hand_760', 'nonRA_right_hand_816', 'nonRA_right_hand_19', 'nonRA_right_hand_803', 'nonRA_right_hand_240', 'nonRA_right_hand_72', 'nonRA_right_hand_282', 'nonRA_right_hand_285', 'nonRA_right_hand_841', '右手 - ナカザワyuko', 'nonRA_right_hand_438', 'nonRA_right_hand_746', 'nonRA_right_hand_537', '16938937785752280696060118810028 - ローストビーフ', 'IMG_9428 - じゅじゅ', 'IMG_7065 - ネギガナイトユウキ', 'nonRA_right_hand_496', 'nonRA_right_hand_777', 'IMG_1797 - Ho2O hO2O', 'nonRA_right_hand_137', 'nonRA_right_hand_231', 'nonRA_right_hand_343', 'nonRA_right_hand_451', 'nonRA_right_hand_489', 'nonRA_right_hand_752', 'nonRA_right_hand_794', 'PXL_20230904_095935733 - ごろはな', 'nonRA_right_hand_736', 'nonRA_right_hand_82', 'nonRA_right_hand_481', '右手 - むんぺん', 'nonRA_right_hand_215', 'nonRA_right_hand_91', 'nonRA_right_hand_546', 'nonRA_right_hand_753', 'nonRA_right_hand_858', 'nonRA_right_hand_514', 'nonRA_right_hand_202', 'nonRA_right_hand_390', 'nonRA_right_hand_554', 'nonRA_right_hand_117', 'nonRA_right_han ...

# %%
# right_hand_filenameカラムの欠損値の位置を確認
missing_values = df[df['right_hand_filename'].isna() | df['right_hand_filename'].astype(str).str.strip() == '']
if not missing_values.empty:
    print(missing_values[['time_stamp', 'right_hand_filename']])
else:
    print("No missing values found.")
# Out:
# No missing values found.

# %%
# right_hand_filenameカラムの欠損値の位置を確認
missing_values = df[df['right_hand_filename'].isna() | df['right_hand_filename'].astype(str).str.strip() == '']
if not missing_values.empty:
    print(missing_values[['time_stamp', 'right_hand_filename']])
else:
    print("No missing values found.")
# Out:
# No missing values found.

# %%
print(df.columns)
# Out:
# Index(['time_stamp', 'informed_consent', 'age', 'female', 'RA', 'arthralgia',
#        'right_hand_url', 'left_hand_url', 'crowdworks_username',
#        'right_hand_filename', 'left_hand_filename'],
#       dtype='object')

# %% [markdown]
# やはりファイル数の確認を行う。

# %%
# 対象のディレクトリ
target_dir = "/content/drive/MyDrive/OptPhotoFiles/optPhotoFiles/nonRA/nonRA_Right_Hand_3rd"

# ファイル数を計算
file_count = sum([len(files) for _, _, files in os.walk(target_dir)])

print(f"Total number of files in {target_dir}: {file_count}")
# Out:
# Total number of files in /content/drive/MyDrive/OptPhotoFiles/optPhotoFiles/nonRA/nonRA_Right_Hand_3rd: 1207

# %% [markdown]
# 同様の作業を/content/drive/MyDrive/OptPhotoFiles/optPhotoFiles/nonRA/nonRA_Left_Hand_2ndにも施行する。

# %%
# ファイル名を統一するディレクトリ
src_dir_2nd = "/content/drive/MyDrive/OptPhotoFiles/optPhotoFiles/nonRA/nonRA_Left_Hand_2nd"
dst_dir_3rd = "/content/drive/MyDrive/OptPhotoFiles/optPhotoFiles/nonRA/nonRA_Left_Hand_3rd"

# optPhotoTable_controlsのパス (適切なパスに変更してください)
optPhotoTable_controls_path = "/content/drive/MyDrive/OptPhotoFiles/opyPhotoTable/optPhotoTable_controls.csv"

# optPhotoTable_controlsを読み込む
optPhotoTable_controls = pd.read_csv(optPhotoTable_controls_path)

# ディレクトリが存在しない場合、新規作成
if not os.path.exists(dst_dir_3rd):
    os.makedirs(dst_dir_3rd)

# ファイル名の統一と移動
for index, row in optPhotoTable_controls.iterrows():
    original_name = row['left_hand_filename']  # この部分はoptPhotoTable_controlsのカラム名に合わせて変更してください
    new_name = f"nonRA_left_hand_{index + 1}_.jpg"

    src_file_path = os.path.join(src_dir_2nd, original_name)
    dst_file_path = os.path.join(dst_dir_3rd, new_name)

    if os.path.exists(src_file_path):
        shutil.copy2(src_file_path, dst_file_path)

    # optPhotoTable_controlsに新しいファイル名を追加
    optPhotoTable_controls.at[index, 'filename'] = new_name

# optPhotoTable_controlsを更新
optPhotoTable_controls.to_csv(optPhotoTable_controls_path, index=False)

print("Process completed!")

# %% [markdown]
# やはりファイル数の確認を行う。

# %%
# 対象のディレクトリ
target_dir = "/content/drive/MyDrive/OptPhotoFiles/optPhotoFiles/nonRA/nonRA_Left_Hand_3rd"

# ファイル数を計算
file_count = sum([len(files) for _, _, files in os.walk(target_dir)])

print(f"Total number of files in {target_dir}: {file_count}")
# Out:
# Total number of files in /content/drive/MyDrive/OptPhotoFiles/optPhotoFiles/nonRA/nonRA_Left_Hand_3rd: 685

# %% [markdown]
# このコードを実行すると、指定した手順に従って処理が行われます。ただし、optPhotoTable_controls の正確なカラム名やパスに関する情報が不足しているため、必要に応じてコードの適切な部分を修正してください。

# %% [markdown]
# #rembgライブラリを使用した背景の削除
# /content/drive/MyDrive/OptPhotoFiles/optPhotoFiles/nonRA/nonRA_Right_Hand_3rdに含まれている画像は、非常に雑多な背景のなかに手背の画像が撮影されています。背景が学習に悪影響を及ぼさないように、背景を削除します。ライブラリrembgのremoveとnew_sessionを使用してください。
# 背景を削除した画像は、/content/drive/MyDrive/OptPhotoFiles/optPhotoFiles/nonRA/nonRA_Right_Hand_4thに格納して、/content/drive/MyDrive/OptPhotoFiles/optPhotoFiles/nonRA/nonRA_Right_Hand_3rdのファイルが破損しないようにした。

# %%
# %pip install rembg

import os
from rembg import remove
from concurrent.futures import ProcessPoolExecutor

def remove_bg_from_file(file_path, dst_dir):
    with open(file_path, "rb") as f:
        img = f.read()
        output = remove(img)

    dst_file_path = os.path.join(dst_dir, os.path.basename(file_path))
    with open(dst_file_path, "wb") as f_out:
        f_out.write(output)

# 画像の背景を削除するディレクトリ
src_dir = "/content/drive/MyDrive/OptPhotoFiles/optPhotoFiles/nonRA/nonRA_Right_Hand_3rd"
dst_dir = "/content/drive/MyDrive/OptPhotoFiles/optPhotoFiles/nonRA/nonRA_Right_Hand_4th"

# ディレクトリが存在しない場合、新規作成
if not os.path.exists(dst_dir):
    os.makedirs(dst_dir)

file_paths = [os.path.join(src_dir, file) for file in os.listdir(src_dir) if file.lower().endswith(('.png', '.jpg', '.jpeg'))]

# Use all available CPU cores for parallel processing
with ProcessPoolExecutor() as executor:
    executor.map(remove_bg_from_file, file_paths, [dst_dir] * len(file_paths))

print("Background removal and saving to new directory completed!")

# %% [markdown]
# 最終的なファイル数の確認を行う。

# %%
# 対象のディレクトリ
target_dir = "/content/drive/MyDrive/OptPhotoFiles/optPhotoFiles/nonRA/nonRA_Right_Hand_4th"

# ファイル数を計算
file_count = sum([len(files) for _, _, files in os.walk(target_dir)])

print(f"Total number of files in {target_dir}: {file_count}")
# Out:
# Total number of files in /content/drive/MyDrive/OptPhotoFiles/optPhotoFiles/nonRA/nonRA_Right_Hand_4th: 687

# %%
# 画像の背景を削除するディレクトリ
src_dir = "/content/drive/MyDrive/OptPhotoFiles/optPhotoFiles/nonRA/nonRA_Left_Hand_3rd"
dst_dir = "/content/drive/MyDrive/OptPhotoFiles/optPhotoFiles/nonRA/nonRA_Left_Hand_4th"

# ディレクトリが存在しない場合、新規作成
if not os.path.exists(dst_dir):
    os.makedirs(dst_dir)

file_paths = [os.path.join(src_dir, file) for file in os.listdir(src_dir) if file.lower().endswith(('.png', '.jpg', '.jpeg'))]

# Use all available CPU cores for parallel processing
with ProcessPoolExecutor() as executor:
    executor.map(remove_bg_from_file, file_paths, [dst_dir] * len(file_paths))

print("Background removal and saving to new directory completed!")

# %% [markdown]
# rembgは、バックグラウンドの削除のためのディープラーニングモデルを基盤としていますが、現行のバージョンではGPUをサポートしていません。したがって、直接のGPUの利用は難しいです。
#
# しかしながら、高速化のアプローチとして以下の方法が考えられます：
#
# 並行処理: 複数の画像の背景削除を同時に行うことで、全体の処理時間を短縮することができます。Pythonのconcurrent.futuresを使用して、複数のCPUコアでの並行処理を実現します。

# %% [markdown]
# 最終的なファイル数の確認を行う。

# %%
# 対象のディレクトリ
target_dir = "/content/drive/MyDrive/OptPhotoFiles/optPhotoFiles/nonRA/nonRA_Left_Hand_4th"

# ファイル数を計算
file_count = sum([len(files) for _, _, files in os.walk(target_dir)])

print(f"Total number of files in {target_dir}: {file_count}")
# Out:
# Total number of files in /content/drive/MyDrive/OptPhotoFiles/optPhotoFiles/nonRA/nonRA_Left_Hand_4th: 312
